# %%
#QUESTION 1
import math
limit=1000
#FUNCTIONS
def isPrime(num):
    flag=1
    if num > 1:
        for i in range(2,num):
            if (num % i) == 0:
                flag=0
                break
            else:
                flag=1
    else:
        return 0
    if flag==1:
        return 1
    else:
        return 0

    
def rotation(n):
  rotations =[]
  for i in range( len( str(n) ) ):
    m = int( str(n)[i:] + str(n)[:i] )
  
    rotations.append(m)
  return rotations

def rotationPrime(returnedlist):
    primeflag=1
    for check in range(len(returnedlist)):
            if isPrime(returnedlist[check]):
                primeflag=1 
            else:
                primeflag=0
                break
    return primeflag

#MAIN
pf=1
count=0
for i in range(2,limit):
    
    if isPrime(i):
        returnedlist=rotation(i) 
        pf=rotationPrime(returnedlist)
        count=count+pf
        if pf==1:
            print(i,end=" ")
            
print("\ncount ",count)
# Out:
# 2 3 5 7 11 13 17 31 37 71 73 79 97 113 131 197 199 311 337 373 719 733 919 971 991
# count  25

# %%
#QUESTION 2
def primeList(limit):
    myPrimelist=[]
    for i in range(1,limit):
        flag=1
        if i > 1:
            for j in range(2,i):
                if (i % j) == 0:
                    flag=0
                    break
                else:
                    flag=1
        else:
            flag=0
        if flag==1:
            myPrimelist.append(i)
    return myPrimelist


plistreturned=primeList(1000)

count=0
highest=0
length=len(plistreturned)
checkcount=0
while count <= length: 
    i = 0
    while(i<(length-count)):
        substring = plistreturned[i:i+count]
        subSum = sum(substring)
        if(subSum < 1000):
            if(subSum in plistreturned):
                
                if(count>checkcount):
                    checkcount=count   
                    highest = subSum
                    
                    
                break
            else: 
                i+=1
        else:
            break
    count += 1
    
print(highest)
# Out:
# 953

# %%
#q3
def primeList(limit):
    myPrimelist=[]
    for i in range(1,limit):
        flag=1
        if i > 1:
            for j in range(2,i):
                if (i % j) == 0:
                    flag=0
                    break
                else:
                    flag=1
        else:
            flag=0
        if flag==1:
            myPrimelist.append(i)
    return myPrimelist

def isPrime(num):
    flag=1
    if num > 1:
        for i in range(2,num):
            if (num % i) == 0:
                flag=0
                break
            else:
                flag=1
    else:
        return 0
    if flag==1:
        return 1
    else:
        return 0
    
def isPrimeList(ret_list):
    primeflag=1
    for check in range(len(ret_list)):
            if isPrime(ret_list[check]):
                primeflag=1 
            else:
                primeflag=0
                break
    return primeflag

def leftToRight(number):
    count=0
    temp=number
    leftRightList=[]
    while(temp>0):
        count=count+1
        temp=temp//10
       
    while count > 1:
        number = number%10 ** (count - 1)
        
        leftRightList.append(number)
        count=count-1
   
    return leftRightList
    
def rightToLeft(number):
    rightToLeft=[]
    while(number >= 10):
        digit = number % 10
        number = int(number / 10)
        rightToLeft.append(number)
   
    return rightToLeft

#main
mypList=primeList(1000) 
truckList=[]
counter=11
L_list=[]
R_list=[]
for i in range(4,len(mypList)):
    
    L_list=leftToRight(mypList[i])
    
    R_list=rightToLeft(mypList[i])
    
    if isPrimeList(L_list) and isPrimeList(R_list):
        truckList.append(mypList[i])
        print(mypList[i])
        counter=counter-1
    if(counter==0):
        break
        
totalsum=sum(truckList)
print("Result is : ",totalsum)
# Out:
# 23
# 37
# 53
# 73
# 313
# 317
# 373
# 797
# Result is :  1986

# %%
#q4

def reverseNumber(num):
    rev = 0
  
    while(num > 0): 
        a = num % 10
        rev = rev * 10 + a 
        num = num // 10
      
    return rev

def isPalindrome(num):
    temp=num
    rev=0
    while(num>0):
        dig=num%10
        rev=rev*10+dig
        num=num//10
        
    if(temp==rev):
        return 1
    else:
        return 0
    
def isLychrel(number):
    iterator=0
    temp=number
    while(iterator!=50):
        rev=reverseNumber(temp)
        sumnum=rev+temp
        
       
        
        if(isPalindrome(sumnum)):
            return 0
        else:
            iterator=iterator+1
            temp=sumnum
    
    return 1
#MAIN
count=0
for i in range(10000):
       if isLychrel(i):
            count=count+1

print("Lychrel numbers below ten-thousand are: ",count)
# Out:
# Lychrel numbers below ten-thousand are:  249

# %%
  class CircularQueue(): 
  
    # constructor 
    def __init__(self, size): # initializing the class 
        self.size = size 
          
        # initializing queue with none 
        self.queue = [None for i in range(size)]  
        self.front = self.rear = -1
  
    def enqueue(self, data): 
          
        # condition if queue is full 
        if ((self.rear + 1) % self.size == self.front):  
            print(" Queue is Full\n") 
              
        # condition for empty queue 
        elif (self.front == -1):  
            self.front = 0
            self.rear = 0
            self.queue[self.rear] = data 
        else: 
              
            # next position of rear 
            self.rear = (self.rear + 1) % self.size  
            self.queue[self.rear] = data 
              
    def dequeue(self): 
        if (self.front == -1): # codition for empty queue 
            print ("Queue is Empty\n") 
              
        # condition for only one element 
        elif (self.front == self.rear):  
            temp=self.queue[self.front] 
            self.front = -1
            self.rear = -1
            return temp 
        else: 
            temp = self.queue[self.front] 
            self.front = (self.front + 1) % self.size 
            return temp 

    def getfront_value(self):
        if self.front==-1:
            return "empty queue"
        else:
            mydata=self.queue[self.rear]
            return mydata

    def isEmpty(self):
        if(self.front == -1):  
            return 1
        else:
            return 0
    def display(self): 
      
        # condition for empty queue 
        if(self.front == -1):  
            print ("Queue is Empty") 
  
        elif (self.rear >= self.front): 
            print("Elements in the circular queue are:",  
                                              end = " ") 
            for i in range(self.front, self.rear + 1): 
                print(self.queue[i], end = " ") 
            print () 
  
        else: 
            print ("Elements in Circular Queue are:",  
                                           end = " ") 
            for i in range(self.front, self.size): 
                print(self.queue[i], end = " ") 
            for i in range(0, self.rear + 1): 
                print(self.queue[i], end = " ") 
            print ()

# %%
#q5 main
sizee=5
minval=999999
q=CircularQueue(sizee)
q.enqueue(5)
q.enqueue(20)
q.enqueue(3)
q.enqueue(40)
q.enqueue(2)


q.display()

if not q.isEmpty():
    start=q.dequeue()
    end=q.getfront_value()




    while(start!=end):
        if start<minval:
            minval=start
        
        q.enqueue(start)
    
        if not q.isEmpty():
            start=q.dequeue()
        
        q.enqueue(start)

    if(minval>start):
        minval=start
    
    print("min: ",minval)
else:
    print("queue is empty")
# Out:
# Elements in the circular queue are: 5 20 3 40 2
#  Queue is Full
#
#  Queue is Full
#
#  Queue is Full
#
# min:  2

# %%
#question 6:

class Queue:
    def __init__(self):
        self.items = []
        self.size = 0
 
    def is_empty(self):
        return self.items == []
 
    def enqueue(self, data):
        self.size += 1
        self.items.append(data)
 
    def dequeue(self):
        self.size -= 1
        return self.items.pop(0)
 
    def get_size(self):
        return self.size
    
    def dis(self):
        if self.size>0:
            print(self.items)


class Stack:
    def __init__(self):
        self.Q1 = Queue()
    
    def is_empty(self):
        return self.Q1.is_empty()
    
    def push(self, data):
        self.Q1.enqueue(data)
    
    def pop(self):
        if not self.Q1.is_empty():
            for _ in range(self.Q1.get_size() - 1):
                dequeued = self.Q1.dequeue()
                self.Q1.enqueue(dequeued)
            return self.Q1.dequeue()
        else:
            return "queue is empty"
    
    def displayy(self):
        if not (self.Q1.is_empty()):
            self.Q1.dis()
        else:
            print("stack is empty")
    
#main:
s=Stack()
s.push(7)
s.push(8)
s.push(9)
s.displayy()
print("popped: ",s.pop())
print("poped: ",s.pop())
print("poped: ",s.pop())

s.displayy()
# Out:
# [7, 8, 9]
# popped:  9
# poped:  8
# poped:  7
# stack is empty
